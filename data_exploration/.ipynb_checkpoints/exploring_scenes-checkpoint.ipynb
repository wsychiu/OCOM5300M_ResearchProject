# %% [markdown]
# # To-Do next:
# 1. ~~Make `scene_path` update using `get_scene_path`~~
# 2. ~~Update `scene` in `sim_settings` to use the new `scene_path`~~
# 3. ~~Fix the positioning of agent on the map (done?)~~
# 4. ~~Create a video showing the agent spinning around to demonstrate environment~~
# 5. Check to see if there is a better way to account for agent height (?)
# 6. ~~Work out 360 view~~ _(Assuming that this is not required for now)_
# 7. ~~Work out prompt for agent to describe task~~
# 8. ~~Hook up a ViT~~
# 9. ~~Make agent take a series of steps~~
# 10. ~~Plot trajectory on a map~~
# 11. ~~Try using GPT4 LLM as decision-maker~~
# 12. ~~Try injecting a panoramic view into the decision maker to help ground the decision making~~ (limited / no noticeable benefit)
# 13. ~~Try injecting a panoramic view into the view description~~ (limited / no noticeable benefit)
# 14. ~~Try injecting the navigation instructions into the view descriptions~~ (some benefit, but is leading to stronger confidence in hallucinations)
# 15. ~~Make agent able to iterate through multiple trajectories~~
# 16. ~~Make agent able to iterate through multiple scenes~~
# 17. Try using GPT4 LLM with full conversation history as decision-maker
# 18. Try using GPT4 to self-prompt
# 19. Try creating an orthogonal orientator?
# 20. Provide agent with environment collision data
# 21. Test checking the chosen direction view after selecting an initial action
# 22. ~~Check error distance per action taken~~
# 23. ~~(tomorrow) Return an output dictionary of reasoning and action taken per step (for posterity?)~~
# 24. (tomorrow) Run different scans
# 25. (tomorrow) Run multiple scans
# 26. (tomorrow) Plot error distances
#
# # Major milestones
# 1. ~~Map agent in environment~~
# 2. ~~Agent random-walk with position trace~~
# 3. Work out 360 view
# 4. ~~Hook up vision transformer~~
# 5. ~~Hook up LLM~~
# 7. Hook up second vision transformer
# 8. ??
# 9. Write-up

# %% [markdown]
# # Basic Schematic

# %% [markdown]
# ![Basic Schematic of Modelling Approach](basic_schematic.drawio.png)

# %% [markdown]
# # Preamble
# This section is used to set up the workbook by:
# 1. Importing required modules
# 2. Establishing Folder Paths and Directories
# 3. Defining required functions
#
#
# ## Preamble 1: Importing required modules

# %%
# Required imports
import os
import json
import numpy as np
import pandas as pd
import random
import imageio
import magnum as mn
from PIL import Image
from matplotlib import pyplot as plt
import math
import cv2

import habitat_sim
from habitat_sim.utils import common as utils
from habitat_sim.utils import viz_utils as vut
from habitat.utils.visualizations import maps
import magnum as mn

import torch
from transformers import Qwen2VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from qwen_vl_utils import process_vision_info

from openai import OpenAI
# Out:
# PluginManager::Manager: duplicate static plugin StbImageImporter, ignoring
# PluginManager::Manager: duplicate static plugin GltfImporter, ignoring
# PluginManager::Manager: duplicate static plugin BasisImporter, ignoring
# PluginManager::Manager: duplicate static plugin AssimpImporter, ignoring
# PluginManager::Manager: duplicate static plugin AnySceneImporter, ignoring
# PluginManager::Manager: duplicate static plugin AnyImageImporter, ignoring

# %% [markdown]
# ## Premable 2: Establishing Folder Paths and Directories

# %%
# setting up folder paths
habitat_dir_path = "/home/wes/habitat/data/"  # path to habitat-sim root directory
rxr_data_path = "/media/wes/Lexar/rxr_data/rxr-data/"  # path to room-across-room data directory
output_dir_path = "/home/wes/Documents/git_ws/OCOM5300M_ResearchProject/outputs/"  # output of data (if published)

scene_dir_path = os.path.join(habitat_dir_path, f"scene_datasets/mp3d/")  # directory of habitat-sim scenes
pose_dir_path = os.path.join(rxr_data_path, f'pose_traces/rxr_train/')  # directory of the room-across-rom poses
mp3d_scene_config = os.path.join(scene_dir_path, f"mp3d.scene_dataset_config.json") # filepath of Matterport 3D scene configuration file

scene_path = ''

annotations_fname = "rxr_train_guide.jsonl/rxr_train_guide.json"  # filepath to the training annotations provided by RxR
annotations_path = os.path.join(rxr_data_path, annotations_fname)

# %%
# checking that paths exist
print(f'Exists: {os.path.exists(scene_dir_path)} \t scene_dir_path: {scene_dir_path}')
print(f'Exists: {os.path.exists(pose_dir_path)} \t pose_dir_path: {pose_dir_path}')
print(f"Exists: {os.path.exists(mp3d_scene_config)} \t mp3d_scene_config: {mp3d_scene_config}")
# Out:
# Exists: True 	 scene_dir_path: /home/wes/habitat/data/scene_datasets/mp3d/
# Exists: True 	 pose_dir_path: /media/wes/Lexar/rxr_data/rxr-data/pose_traces/rxr_train/
# Exists: True 	 mp3d_scene_config: /home/wes/habitat/data/scene_datasets/mp3d/mp3d.scene_dataset_config.json

# %% [markdown]
# ## Preamble 3: Defining required functions
# ### 3.1: Functions to update variables relating to path changes

# %%
# Returns the full filepath of a scene given a scene id (i.e. scan id)
def get_scene_path(scene_id):
    global scene_dir_path
    return os.path.join(scene_dir_path, f"{scene_id}/{scene_id}.glb")

# %%
# Propagate the new scene filepath across all relevant dictionaries, etc.
def update_scene_path(scene_id):
    global scene_dir_path
    global sim_settings
    
    scene_path = get_scene_path(scene_id)
    sim_settings['scene'] = scene_path

    return

# %% [markdown]
# ### 3.2: Functions to display observations

# %%
# Displaying a single sample of an observation
def display_sample(rgb_obs, semantic_obs=np.array([]), depth_obs=np.array([])):
    from habitat_sim.utils.common import d3_40_colors_rgb

    rgb_img = Image.fromarray(rgb_obs, mode="RGBA")

    arr = [rgb_img]
    titles = ["rgb", "depth"]
    if semantic_obs.size != 0:
        semantic_img = Image.new("P", (semantic_obs.shape[1], semantic_obs.shape[0]))
        semantic_img.putpalette(d3_40_colors_rgb.flatten())
        semantic_img.putdata((semantic_obs.flatten() % 40).astype(np.uint8))
        semantic_img = semantic_img.convert("RGBA")
        arr.append(semantic_img)
        titles.append("semantic")

    if depth_obs.size != 0:
        depth_img = Image.fromarray((depth_obs / 10 * 255).astype(np.uint8), mode="L")
        arr.append(depth_img)
        titles.append("depth")

    plt.figure(figsize=(12, 8))
    for i, data in enumerate(arr):
        ax = plt.subplot(1, 2, i + 1)
        ax.axis("off")
        ax.set_title(titles[i])
        plt.imshow(data)
    plt.show(block=False)

# Function to create a video when in Continuous Environment
if __name__ == "__main__":
    import argparse

    parser = argparse.ArgumentParser()
    parser.add_argument("--no-display", dest="display", action="store_false")
    parser.add_argument("--no-make-video", dest="make_video", action="store_false")
    parser.set_defaults(show_video=True, make_video=True)
    args, _ = parser.parse_known_args()
    show_video = args.display
    display = args.display
    do_make_video = args.make_video
else:
    show_video = False
    do_make_video = False
    display = False

# %%
# Get observations of current surroundings
#  Assumes 4 observations
def get_current_observations(agent, number_of_captures = 4):
    rotation_size = 360/number_of_captures
    initial_orientation = agent.get_state().rotation
    
    color_observations = []

    for i in range(number_of_captures + 1):  # +1 to return agent back to original orientation
        agent_state = agent.get_state()
        rotation_amount = habitat_sim.utils.quat_from_angle_axis(
            np.deg2rad(-rotation_size * i), np.array([0,1,0]) # Clockwise rotation about the Y-axis
        )
        agent_state.rotation = initial_orientation * rotation_amount
        
        agent.set_state(agent_state)
        observations = sim.get_sensor_observations()
        color_observations.append(observations["color_sensor"])
    
    agent_views = {
        "forward" : color_observations[0],
        "right" : color_observations[1],
        "behind" : color_observations[2],
        "left" : color_observations[3]
    }
    
    return agent_views, color_observations[:-1]

# %%
# Function to create basic forward-centred panoramic image
def get_current_panorama(agent, number_of_captures = 5):
    rotation_size = 360/number_of_captures
    initial_orientation = agent.get_state().rotation
    
    pano_observations = []

    for i in range(number_of_captures + 1):  # +1 to return agent back to original orientation
        agent_state = agent.get_state()
        rotation_amount = habitat_sim.utils.quat_from_angle_axis(
            np.deg2rad(-rotation_size * i), np.array([0,1,0]) # Clockwise rotation about the Y-axis
        )
        agent_state.rotation = initial_orientation * rotation_amount
        
        agent.set_state(agent_state)
        observations = sim.get_sensor_observations()
        pano_observations.append(observations["color_pano_sensor"])

    pano_observations = pano_observations[:-1]
    
    return cv2.hconcat(pano_observations[-2:] + pano_observations[:-2])

# %% [markdown]
# ### 3.3: Functions to configure Habitat-Sim Simulator Settings

# %%
# Setting up default sim settings
rgb_sensor = True
depth_sensor = True
semantic_sensor = False
seed = 1
number_images_for_panorama = 4 # number of images required for a full 360 degree panorama to be created

sim_settings = {
    "width": 256,  # Spatial resolution of the observations
    "height": 256,
    "scene": scene_path,  # Scene path
    "scene_dataset": mp3d_scene_config,  # the scene dataset configuration files
    "default_agent": 0,
    "sensor_height": 1.0,  # Height of sensors in meters
    "color_sensor": rgb_sensor,  # RGB sensor
    "depth_sensor": depth_sensor,  # Depth sensor
    "semantic_sensor": semantic_sensor,  # Semantic sensor
    "seed": seed,  # used in the random navigation
    "enable_physics": False,  # kinematics only    
    "hfov" : 90, #360 / number_images_for_panorama
    "forward_displacement" : 1.0 # metres moving forward
}

# %%
# Habitat-sim Simulator Factory
#  Creates a simulator based on the simulator settings provided
def make_cfg(settings):
    sim_cfg = habitat_sim.SimulatorConfiguration()
    sim_cfg.gpu_device_id = 0
    sim_cfg.scene_id = settings["scene"]
    sim_cfg.scene_dataset_config_file = settings["scene_dataset"]
    sim_cfg.enable_physics = settings["enable_physics"]

    sensor_specs = []

    # RGB sensor specs: used for colour observations for the agent
    color_sensor_spec = habitat_sim.CameraSensorSpec()
    color_sensor_spec.uuid = "color_sensor"
    color_sensor_spec.sensor_type = habitat_sim.SensorType.COLOR
    color_sensor_spec.resolution = [settings["height"], settings["width"]]
    color_sensor_spec.position = [0.0, settings["sensor_height"], 0.0]
    color_sensor_spec.sensor_subtype = habitat_sim.SensorSubType.PINHOLE
    color_sensor_spec.hfov = settings["hfov"]
    sensor_specs.append(color_sensor_spec)

    # RGB panorama sensor specs: used to create a 360 degree panorama, with "forward" as centre image
    color_sensor_pano_spec = habitat_sim.CameraSensorSpec()
    color_sensor_pano_spec.uuid = "color_pano_sensor"
    color_sensor_pano_spec.sensor_type = habitat_sim.SensorType.COLOR
    color_sensor_pano_spec.resolution = [settings["height"], settings["width"]]
    color_sensor_pano_spec.position = [0.0, settings["sensor_height"], 0.0]
    color_sensor_pano_spec.sensor_subtype = habitat_sim.SensorSubType.PINHOLE
    color_sensor_pano_spec.hfov = 360/5
    sensor_specs.append(color_sensor_pano_spec)

    # Depth sensor specs
    depth_sensor_spec = habitat_sim.CameraSensorSpec()
    depth_sensor_spec.uuid = "depth_sensor"
    depth_sensor_spec.sensor_type = habitat_sim.SensorType.DEPTH
    depth_sensor_spec.resolution = [settings["height"], settings["width"]]
    depth_sensor_spec.position = [0.0, settings["sensor_height"], 0.0]
    depth_sensor_spec.sensor_subtype = habitat_sim.SensorSubType.PINHOLE
    depth_sensor_spec.hfov = settings["hfov"]
    sensor_specs.append(depth_sensor_spec)

    # Agent movement: Predefined agent movements
    agent_cfg = habitat_sim.agent.AgentConfiguration()
    agent_cfg.sensor_specifications = sensor_specs
    agent_cfg.action_space = {
        "move_forward" : habitat_sim.agent.ActionSpec(
            "move_forward", habitat_sim.agent.ActuationSpec(amount=settings["forward_displacement"])
        ),
        "turn_left":habitat_sim.agent.ActionSpec(
            "turn_left", habitat_sim.agent.ActuationSpec(amount=90.0)
        ),
        "turn_right":habitat_sim.agent.ActionSpec(
            "turn_right", habitat_sim.agent.ActuationSpec(amount=90.0)
        ),
        "turn_around":habitat_sim.agent.ActionSpec(
            "turn_right", habitat_sim.agent.ActuationSpec(amount=180.0)
        )
    }
    return habitat_sim.Configuration(sim_cfg, [agent_cfg])

# %% [markdown]
# ### 3.4: Functions to map agent position to a topdown map of the environment

# %%
# convert 3d points to 2d topdown coordinates
def convert_points_to_topdown(pathfinder, points, meters_per_pixel = 0.025):
    points_topdown = []
    bounds = pathfinder.get_bounds()
    for point in points:
        # convert 3D x,z to topdown x,y
        px = (point[0] - bounds[0][0]) / meters_per_pixel
        py = (point[2] - bounds[0][2]) / meters_per_pixel
        points_topdown.append(np.array([px, py]))
    return points_topdown


# display a topdown map with matplotlib
def display_map(topdown_map, key_points=None, gold_path=None):
    plt.figure(figsize=(12, 8))
    ax = plt.subplot(1, 1, 1)
    ax.axis("off")
    plt.imshow(topdown_map)
    
    # plot points visited
    if key_points is not None:
        xs = np.array([point[0] for point in key_points])
        ys = np.array([point[1] for point in key_points])
        plt.plot(xs, ys, marker="o", markersize=6, alpha=0.8, color='lightsteelblue')

    # plot points visited in the provided by 'gold label' RxR data
    if gold_path is not None:
        xs = np.array([point[0] for point in gold_path])
        ys = np.array([point[1] for point in gold_path])
        plt.plot(xs, ys, marker="x", markersize=4, linestyle='dashed', linewidth=1, alpha=0.5, color='gold')
    
    plt.show(block=False)

# %%
# Draw the map of the current scene
def draw_map(agent, scene_id, meters_per_pixel = 0.025, height = 1, agent_radius_px = 8):
    print(f"Showing map for scene: {scene_id}")
    print(f"The NavMesh bounds are: {str(sim.pathfinder.get_bounds())}")
    
    agent_pos = agent.get_state().position
    agent_forward = utils.quat_to_magnum(agent.get_state().rotation).transform_vector(mn.Vector3(0,0,-1.0))
    agent_orientation = math.atan2(agent_forward[0], agent_forward[2])

    topdown_map = maps.get_topdown_map(
        sim.pathfinder, height=agent_pos[1], meters_per_pixel = meters_per_pixel
    )
    recolor_map = np.array(
        [[255,255,255],[128,128,128], [0,0,0]], dtype=np.uint8
    )
    topdown_map = recolor_map[topdown_map]

    grid_dimensions = (topdown_map.shape[0], topdown_map.shape[1])
    agent_grid_pos = maps.to_grid(agent_pos[2], agent_pos[0], grid_dimensions, pathfinder=sim.pathfinder)
    maps.draw_agent(topdown_map, agent_grid_pos, agent_orientation, agent_radius_px=agent_radius_px)

    return topdown_map

# %% [markdown]
# ### 3.5: Reading and loading RxR data

# %%
# Utility function to read RxR data and return it as a dataframe
def json_to_df(file_path):
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            data.append(json.loads(line))

    return pd.DataFrame(data)

# %%
# Takes a scan id (aka: scene_id) and annotation file path
# Returns a list of scene_ids and associated instruction_ids and instructions
# If scan_id is provided, then only annotations and instruction ids for the scene_id is returned
def get_rxr_annotations(annotations_path, scan_id_list = 'None'):
    if not os.path.exists(annotations_path):
        print(f'Annotation path not found: {annotations_path}')
        return

    n_records = 0
    rxr_annotations = {}
    # Turning entire annotation json into dataframe
    df_rxr = json_to_df(annotations_path)
    
    # Focusing on just the english instructions for now
    df_rxr = df_rxr[df_rxr['language']=='en-US']

    # If no scan_id provided, go through entire dataset
    if scan_id_list == 'None':
        scan_id_list = df_rxr['scan'].unique().tolist()

    # Creates a dictionary that matches instructions and scenes
    # key = scan_id
    # value = [{instruction_id}:{instructions}, ...]
    for scan_id in scan_id_list:
        rxr_annotations[scan_id] = df_rxr[df_rxr['scan']==scan_id][['instruction_id', 'instruction']].to_dict('records')
        n_records += len(rxr_annotations[scan_id])

    return scan_id_list, rxr_annotations, n_records

# %%
# Takes an instruction_id and returns the pose trace
#  Pose trace: the list of positions (and rotations) the gold path traveled to
def get_pose_trace(pose_dir_path, instruction_id):
    instruction_id = ('000000' + str(instruction_id))[-6:] # Appending zeros to match file name nomenclature
    pose_trace_path = os.path.join(pose_dir_path, f'{instruction_id}_guide_pose_trace.npz')
    if not os.path.exists(pose_trace_path):
        print(f'pose_trace_path not found: {pose_trace_path}')
        return

    pose_trace = np.load(pose_trace_path)['extrinsic_matrix']
    return pose_trace

# %%
# Takes a pose trace dataset and returns a list of all unique positions
#  and a list of the rotation based on that unique position
def get_unique_poses(pose_trace):
    unique_position_list = np.zeros((1,3))
    unique_rotation_list = np.zeros((1,3,3))
    for pose in pose_trace:
        if not np.all(np.isin(np.round(pose[:3,3], 2), unique_position_list)):
            unique_position_list = np.append(unique_position_list, np.round(np.array(pose[:3,3]), 2).reshape(1,3), axis=0)  # position can be rounded to account for slight offsets during image capture
            unique_rotation_list = np.append(unique_rotation_list, np.array(pose[:3,:3]).reshape(1,3,3), axis=0) # rotation should not be rounded to maintain precise viewing angles

    return np.squeeze(unique_position_list[1:]), unique_rotation_list[1:]

# %% [markdown]
# ### 3.6: Functions to generate outputs from VLM and LLM

# %%
def generate_outputs_qwen2(model, processor, messages):
    text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    image_inputs, video_inputs = process_vision_info(messages)
    inputs = processor(
            text = [text],
            images = image_inputs,
            videos = video_inputs,
            padding = True,
            return_tensors = "pt",
        )
    
    inputs = inputs.to("cuda")
    
    generated_ids = model.generate(**inputs, max_new_tokens=128)
    generated_ids_trimmed = [out_ids[len(in_ids):] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)]
    output_text = processor.batch_decode(generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False)

    return output_text[0]

# %%
def generate_outputs_openai(client, messages, model="gpt-4o-mini"):
    completion = client.chat.completions.create(
        model = model,
        messages = messages
    )
    
    return completion.choices[0].message.content

# %% [markdown]
# ### 3.7: Functions for agent-environment interaction

# %%
def take_action(agent, action, env_settings=None):
    '''
    control_sequence = []
    
    sim_time = env_settings["sim_time"]
    control_frequency = env_settings["control_frequency"]
    frame_skip = env_settings["frame_skip"]
    fps = control_frequency * frame_skip
    '''
    if action != 'Goal Reached':
        action_dict = {
            "Move Forward" : "move_forward",
            "Turn Left" : "turn_left",
            "Turn Right" : "turn_right",
            "Turn to face behind" : "turn_around",
        }
    
        agent.act(action_dict[action])

# %%
# saving time by not taking new observations if simply rotating
# !!!!!!!! Not used yet !!!!!!!!!!!
# !!!!!! To be implemented !!!!!!!!
def estimate_new_observations(action, color_observations, view_description):
    default_order = ["forward", "right", "behind", "left"]
    
    new_agent_views = {}
    new_view_description = {}
    
    if action == "Turn Left":
        new_order = ["left", "forward", "right", "behind"]
    elif action == "Turn Right":
        new_order = ["right", "behind", "left", "forward"]
    elif action == "Turn to face behind you":
        new_order = ["behind", "left", "forward", "right"]

    if action != "Move Forward":
        for i in range(len(default_order)):
            new_agent_views[default_order[i]] = new_order[i]
            new_view_description[default_order[i]] = view_description[new_order[i]]

    return new_agent_views, new_view_description

# %%
# checking to see if the agent can move forward without a collision
def check_step_collision(agent):
    agent_state = agent.get_state()
    
    current_pos = agent_state.position
    #fwd_direction = agent_state.rotation.transform_vector(habitat_sim.geo.FRONT)

    agent_forward = utils.quat_to_magnum(
            agent_state.rotation
        ).transform_vector(mn.Vector3(0, 0, -1.0))
    agent_orientation = math.atan2(agent_forward[0], agent_forward[2])
    
    intended_pos = current_pos + agent_orientation * sim_settings["forward_displacement"]
    is_navigable = sim.pathfinder.is_navigable(intended_pos)
    
    #print(f'Intended position is navigable? {is_navigable}')
    
    return is_navigable, intended_pos

# %% [markdown]
# ### 3.8: Functions to report on performance

# %%
# Finds and returns the geodesic distance between two points
#  in the environment. Returns "null" if no path found
def find_geodesic_distance(agent_positions, gold_end_pos):
    distances = []
    
    path = habitat_sim.ShortestPath()

    if not(isinstance(agent_positions, list)):
        agent_positions = list(agent_positions)

    agent_height_adjustment = np.array(
        [0, gold_end_pos[1] - agent_positions[0][1], 0]
    )
    
    for position in agent_positions:
        path.requested_start = position
        path.requested_end = gold_end_pos - agent_height_adjustment
        found_path = sim.pathfinder.find_path(path)
        distances.append(path.geodesic_distance)
        
    return distances

# %% [markdown]
# ### 3.9: Model prompts

# %%
# Turning the raw instructions from RxR into a more structured series of checkpoints
def infer_navigation_instructions(nav_instructions):
    prompt = f"""I are navigating an indoor environment. My goal is to follow set of instructions to navigate from your starting location to the goal.
    The instructions are: {nav_instructions}.
    
    Divide the instructions into a series of detailed steps using the format below:
    Navigation Checkpoints:
    Starting Point: starting position
    Checkpoint 1: checkpoint_1
    Checkpoint 2: checkpoint_2
    
    Navigation Checkpoints:
    """

    messages = [
        {"role" : "system",
         "content" : prompt
        }
    ]

    output = generate_outputs_qwen2(model_vlm_1, processor_vlm_1, messages)
    #output = generate_outputs_openai(llm_client, messages, model=llm_model)
    
    return output

# %%
# Returns the colour observations of the agent's current position as textual descriptions
#   discretized into the following directions: Forward, 90 degress to the Right, Directly behind, 90 degress to the Left
def generate_text_observations(agent_views, inferred_navigation_instructions, past_action_story):
    view_description = {}
    views = ["forward", "right", "behind", "left"]
    views_alias = ["front", "right", "behind", "left"]

    image_prompts = {
        "forward" : "This is what you see in front of you",
        "left" : "This is what you see to the left of you",
        "right" : "This is what you see to the right of you",
        "behind" : "This is what you see behind you"
    }
   
    for i, view in enumerate(views):
        system_prompt = f"""I am navigating an indoor environment by following a set of Navigation Checkpoints: {inferred_navigation_instructions}
        The actions I have taken up to now are: {past_action_story}
        
        This is what I can see to my {views_alias[i]}.
        Describe what I see in the observation and identify whether this observation contains any points of interest described in the Navigation Checkpoints.
        Start the description with: To my {views_alias[i]} is"""
        messages = [
            {"role" : "system",
             "content" : system_prompt
            },
            {"role" : "user",
             "content" : [
                 {"type":"text", "text": system_prompt},
                 {"type":"image", "image":Image.fromarray(agent_views[view])}
             ]
            }
        ]
        view_description[view] = generate_outputs_qwen2(model_vlm_1, processor_vlm_1, messages)

    return view_description

# %%
# Prompts the LLM to make a decision on which action to take next and to explain the "reasoning" for taking this action
def decide_next_step(inferred_nav_instructions, view_description, past_actions):
    
    allowable_actions = ['Turn Right', 'Turn to face behind', 'Turn Left']

    # Only allow forward movement if it will not result in a collision
    forward_is_navigable, _ = check_step_collision(agent)
    if forward_is_navigable:
        allowable_actions = ['Move Forward'] + allowable_actions
   
    prompt_past_actions = f'''Past Actions: {past_actions}.'''
    
    prompt_system = f"""I am navigating an indoor environment by following a series of Navigation Checkpoints.
    I am provided a history of all of the steps I have previously taken and the visual observations of the environment based on my current location.
    My task is to evaluate all of my current observations and determine which direction I should move to next.

    I must answer in the following format:
    Current Location: State my current estimated location based on the observations provided
    Reasoning: State which Navigation Checkpoints I have already achieved, and which Navigation Checkpoint I am currently working toward. It may take multiple actions to go from one Navigation Checkpoint to the next Navigation Checkpoint. I can only move to the next checkpoint once the previous one has been achieved. The observation in front of me is the direction I am currently facing. In order to move in any direction other than forward, I must first turn to face that direction.
    Selected Action: State which action I should take in order to progress towards my next Navigation Checkpoint. I must choose only one of these actions: {allowable_actions}
    
    Navigation Checkpoints: {inferred_nav_instructions}

    Past Actions: {prompt_past_actions}
    
    Observations:
    {view_description["forward"]},
    {view_description["right"]},
    {view_description["behind"]},
    {view_description["left"]}
    """

    if forward_is_navigable:
        prompt_assistant = f"""You can only choose from the following actions: {allowable_actions}.
        The action must be stated exactly as shown without any punctuation marks.
        """
    else:
        prompt_assistant = f"""You can only choose from the following actions: {allowable_actions}.
        You cannot Move Forward as there is an obstruction in front of you.
        The action must be stated exactly as shown without any punctuation marks.
        """

    messages = [
        {"role" : "system",
         "content" : prompt_system
        },
        {"role" : "assistant",
         "content" : prompt_assistant
        },
        {"role" : "user",
         "content" : "State which action you should take next"
        },
    ]

    #outputs = generate_outputs_qwen2(model, processor, messages)
    outputs = generate_outputs_openai(client=llm_client, messages=messages, model=llm_model)
    
    return outputs

# %%
# Prompts the LLM to construct a short historical trajectory of past actions and reasoning
def generate_historical_trajectory(inferred_nav_instructions, reasoning=None, selected_action=None, past_actions_story=None):
    
    if reasoning is None:
        return 'I am at the Starting Point and have taken no actions and have achieved no checkpoints yet.'
    
    prompt = f"""I am navigating an indoor environment by following a series of Navigation Checkpoints. My task is to write a summary of the steps I have taken so far and the progress I have made.
    I am provided with:
    Navigation Checkpoints: A series of checkpoints that I am trying to navigate to
    Past Actions: A history of the previous actions I have taken before this step
    Reasoning: The reason I chose to take the latest action: {reasoning}

    Navigation Checkpoints: {inferred_nav_instructions}
    Past Actions: {past_actions_story}
    Reasoning: {reasoning}
    Action I just took: {selected_action}

    In my summary, I will write which Navigation Checkpoints I have already achieved, which action I took and why.
    The narrative must include all of the steps I have taken previously as indicated in my Past Actions, and it must be written in the past tense. I must keep in mind that I can only take one action at a time.
    """

    messages = [
        {"role" : "system",
         "content" : prompt
        },
    ]

    #output = generate_outputs_qwen2(model, processor, messages)[0]
    output = generate_outputs_openai(llm_client, messages)
    
    return output

# %%
# Takes in a position and rotation state and returns an agent state
def snap_to_point(agent_state, agent_position, agent_rotation):
    # Turn rotation matrix into a quaternion
    agent_rotation_quat = mn.Quaternion.from_matrix(mn.Matrix3(agent_rotation))

    agent_state.position = agent_position - np.array([0, sim_settings['sensor_height'], 0]) # Subtract sensor height from agent pose from dataset (as it already includes original sensor height)
    agent_state.rotation = utils.quat_from_magnum(agent_rotation_quat)  # Turn magnum quaternion into habitat-sim quaternion
        
    return agent_state

# %% [markdown]
# ### 3.10: Functions to iterate through data for testing

# %%
# Iterate through a list of scan_ids and all of their associated instructions
# verbose: how much detail to print out
#  = 0: show nothing
#  = 1: return only progress
#  = 2: print progress and LLM decision-making outputs
#  = 3: print everything, including VLM descriptions
# show_observations: how much observation to show
#  = 0: show nothing
#  = 1: show starting position and ending position panorama and agent on map
#  = 2: show everything, including observations at each step
# max_annotations = 0 --> iterate through all available annotations

def iterate_through_scans(scan_id_list, rxr_annotations, max_scans=0, max_annotations=0, max_actions=10, verbose=0, show_observations=0):
    if max_scans!= 0: scan_id_list = scan_id_list[:max_scans]
    
    for scan_id in scan_id_list:
        print(f'Running through scan: {scan_id}')
        outputs = iterate_through_scene_annotations(scan_id, rxr_annotations, max_annotations=max_annotations, max_actions=max_actions, verbose=verbose, show_observations=show_observations)
        results = {scan_id : outputs}

    return results

# %%
# Iterates through the RxR annotations of a selected scene
def iterate_through_scene_annotations(scan_id, rxr_annotations, max_annotations=0, max_actions=10, verbose=0, show_observations=0):   
    # Instantiate an instance of the scene
    update_scene_path(scan_id)
    cfg = make_cfg(sim_settings)
    global sim
    sim = habitat_sim.Simulator(cfg)
    global agent
    agent = sim.get_agent(0)
    
    annotations = rxr_annotations[scan_id]  # Return list of annotations

    if max_annotations != 0: annotations = annotations[:max_annotations]

    # Run through each annotation and calculate the proximity to end state goal
    for annotation in annotations:
        # Get instructions for current annotation data
        instruction_id = annotation['instruction_id']
        nav_instructions = annotation['instruction']
        pose_trace = get_pose_trace(pose_dir_path, instruction_id)

        print(f'Running through instruction: {instruction_id}')

        annotation_outputs = navigate_environment(pose_trace, nav_instructions, max_actions=max_actions, verbose=verbose, show_observations=show_observations)

        outputs = {instruction_id : annotation_outputs}

    sim.close()
    return outputs

# %%
# Attempts to navigate the agent through a given environment and single set of instructions
def navigate_environment(pose_trace, nav_instructions, max_actions=10, verbose=0, show_observations=0):
    # To do:
    #    1. Make use of show_observations
    #    2. Expand verbosity settings

    agent_state = habitat_sim.AgentState(0)
    unique_position_list, unique_rotation_list = get_unique_poses(pose_trace)
    
    # Snapping agent to starting position of instruction
    agent_state = snap_to_point(agent_state, unique_position_list[0], unique_rotation_list[0])
    agent.set_state(agent_state)

    if show_observations == 1:
        # show starting position panorama - forward view is in centre
        pano = get_current_panorama(agent)
        plt.imshow(pano)
        plt.axis("off")
        plt.show()

    # Return Inferred Navigational Checkpoints
    inferred_nav_instructions = infer_navigation_instructions(nav_instructions)

    if verbose == 2:
        print(f"Original navigation instructions:\n{nav_instructions}")
        print()
        print(f"Inferred Navigation Checkpoints:\n{inferred_nav_instructions}")
    
    # Resetting tracking variables
    step_observations = []
    past_actions = []
    positions = []
    reasoning = None
    reasoning_history = []
    view_description_history = []
    selected_action = None
    past_action_story = None

    # Taking steps
    for step in range(max_actions):
        if verbose > 0: print(f"Step: {step+1}")

        # Starting with the past action history to help ground the model
        #  and orientate it in navigation checkpoint progress
        past_action_story = generate_historical_trajectory(inferred_nav_instructions, 
                                                reasoning, # action reasoning from prior step
                                                selected_action, # selected action from prior step
                                                past_action_story # Summary of progress up to prior step
                                               )

        # Getting observations from current location
        agent_views, color_observations = get_current_observations(agent)
        step_observations.append({key:value[:] for key, value in agent_views.items()}) # Saving colour images to display to user
        view_description = generate_text_observations(agent_views, inferred_nav_instructions, past_action_story)

        # Deciding on an action to take based on observations
        reasoning = decide_next_step(inferred_nav_instructions, view_description, past_actions)
        selected_action = reasoning[reasoning.rfind('Selected Action:') + len('Selected Action: '):] # Use some regex later to fix this

        # Taking an action (if goal is not reached)
        if selected_action == "Goal Reached":
            print(f" ---->> Goal has been reached! Ending this trajectory")
            break
        else:
            take_action(agent, selected_action)
        
            # Saving actions taken and positions visited to track agent progress throughout trajectory
            past_actions.append(selected_action)
            positions.append(agent.get_state().position)

        # Displaying results to user depending on verbosity settings
        if verbose >= 2:
            print(f'Summary of past action(s): {past_action_story}')

            # ----------------------------------
            # !! Replace this with a function !!
            # ----------------------------------
            if verbose == 2:
                print(f'Observations:')
                print(f'    Front: {view_description["forward"]}')
                print(f'    Right: {view_description["right"]}')
                print(f'    Behind: {view_description["behind"]}')
                print(f'    Left: {view_description["left"]}')

            print(f'Action Reasoning ----\n{reasoning}')
            print(f'Taking action: {selected_action}')
            print(f'Current position: {positions[-1]}')

        print(f'-------------------')
        print()

        reasoning_history.append(reasoning)
        view_description_history.append(view_description)
        
    # Retrieving observations one more time to get observations from ending position
    agent_views, color_observations = get_current_observations(agent)
    step_observations.append({key:value[:] for key, value in agent_views.items()})

    # Calculating the distance to the goal after each action
    distances = find_geodesic_distance(positions, unique_position_list[-1])

    if verbose >= 2:
        print(f'Actions taken: {past_actions}')
        print(f'Final distance to goal: {distances[-1]}')

    outputs = {
        'inferred_nav_instructions' : inferred_nav_instructions,
        'observations' : step_observations,
        'text_observations' : view_description_history,
        'actions' : past_actions,
        'reasoning' : reasoning_history,
        'visited_points' : positions,
        'gold_path' : unique_position_list
    }
    
    return outputs

# %% [markdown]
# # Running model

# %% [markdown]
# ## Getting data and declaring models

# %%
# getting RxR training data (annotations / instructions)
scan_id_list, rxr_annotations, n_records = get_rxr_annotations(annotations_path)

# %%
# Declaring first VLM: model_vlm1
# Uses Qwen2-VL-7B
model_vlm_1 = Qwen2VLForConditionalGeneration.from_pretrained(
    "Qwen/Qwen2-VL-7B-Instruct",
    torch_dtype=torch.bfloat16,
    attn_implementation="flash_attention_2",
    device_map="auto"
)

processor_vlm_1 = AutoProcessor.from_pretrained("Qwen/Qwen2-VL-7B-Instruct")
# Out:
# Unrecognized keys in `rope_scaling` for 'rope_type'='default': {'mrope_section'}
# You are attempting to use Flash Attention 2.0 without specifying a torch dtype. This might lead to unexpected behaviour
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# Declaring LLM API client: OpenAI
llm_client = OpenAI()
llm_model = "gpt-4o-mini"  # Use gpt-4o-mini as default

# %% [markdown]
# ## Testing on a single scene / scan

# %%
# Running simulation
max_actions = 5
verbose = 2

outputs = iterate_through_scans(scan_id_list, rxr_annotations, max_scans=1, max_annotations=1, max_actions=5, verbose=2, show_observations=0)
# Out:
# Running through scan: SN83YJsR3w2
# Renderer: NVIDIA GeForce RTX 4090/PCIe/SSE2 by NVIDIA Corporation
# OpenGL version: 4.6.0 NVIDIA 550.120
# Using optional features:
#     GL_ARB_vertex_array_object
#     GL_ARB_separate_shader_objects
#     GL_ARB_robustness
#     GL_ARB_texture_storage
#     GL_ARB_texture_view
#     GL_ARB_framebuffer_no_attachments
#     GL_ARB_invalidate_subdata
#     GL_ARB_texture_storage_multisample
#     GL_ARB_multi_bind
#     GL_ARB_direct_state_access
#     GL_ARB_get_texture_sub_image
#     GL_ARB_texture_filter_anisotropic
#     GL_KHR_debug
#     GL_KHR_parallel_shader_compile
#     GL_NV_depth_buffer_float
# Using driver workarounds:
#     no-forward-compatible-core-context
#     nv-egl-incorrect-gl11-function-pointers
#     no-layout-qualifiers-on-old-glsl
#     nv-zero-context-profile-mask
#     nv-implementation-color-read-format-dsa-broken
#     nv-cubemap-inconsistent-compressed-image-size
#     nv-cubemap-broken-full-compressed-image-query
#     nv-compressed-block-size-in-bits
# Running through instruction: 0
# PluginManager::Manager: duplicate static plugin StbImageImporter, ignoring
# PluginManager::Manager: duplicate static plugin GltfImporter, ignoring
# PluginManager::Manager: duplicate static plugin BasisImporter, ignoring
# PluginManager::Manager: duplicate static plugin AssimpImporter, ignoring
# PluginManager::Manager: duplicate static plugin AnySceneImporter, ignoring
# PluginManager::Manager: duplicate static plugin AnyImageImporter, ignoring
# [22:02:34:542855]:[Warning]:[Metadata] SceneDatasetAttributes.cpp(107)::addNewSceneInstanceToDataset : Dataset : 'mp3d' : Lighting Layout Attributes 'no_lights' specified in Scene Attributes but does not exist in dataset, so creating default.
# Original navigation instructions:
# You will start by standing in front of a glass door and on your right is a doorway. Turn around and you will see a doorway to the washroom. Walk towards the doorway and inside the washroom. Once you're there, stand in between the sink and the bathtub and once you're there, you're done.
#
# Inferred Navigation Checkpoints:
# Starting Point: You are standing in front of a glass door.
# Checkpoint 1: On your right is a doorway. Turn around.
# Checkpoint 2: You will see a doorway to the washroom. Walk towards the doorway and inside the washroom.
# Checkpoint 3: Stand in between the sink and the bathtub. Once you're there, you're done.
# Step: 1
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Summary of past action(s): I am at the Starting Point and have taken no actions and have achieved no checkpoints yet.
# Observations:
#     Front: To my front is a white door with a black frame, and to the right of this door is a doorway.
#     Right: To my right is a doorway.
#     Behind: To my behind is a doorway leading to another room.
#     Left: To my left is a doorway leading to another room.
# Action Reasoning ----
# Current Location: In front of a glass door with a black frame.
# Reasoning: I have not yet achieved any Navigation Checkpoints since I am at the Starting Point. I need to turn around to move towards Checkpoint 1 which involves a doorway on my right.
# Selected Action: Turn Right
# Taking action: Turn Right
# Current position: [  0.26      3.89145 -16.09   ]
# -------------------
#
# Step: 2
# Summary of past action(s): So far, I have been navigating the indoor environment with the goal of reaching specific Navigation Checkpoints. I began at the Starting Point, which placed me in front of a glass door with a black frame. At this initial position, I had not yet achieved any Navigation Checkpoints or taken any actions.
#
# Recognizing that I was at the Starting Point and needed to progress, I assessed my surroundings and noted that Checkpoint 1 was located to my right, accessible through a doorway. In order to move towards Checkpoint 1, I decided to turn around. Therefore, my selected action was to turn right.
#
# This recent action, turning right, has brought me one step closer to my goal of reaching Checkpoint 1, though I have not yet completed any checkpoints at this stage. I am now poised to continue on my journey and will likely walk towards the indicated doorway next.
# Observations:
#     Front: To my front is a glass door with a black frame, which appears to be the Starting Point of my navigation task. The door is closed, and beyond it, I can see a glimpse of the interior of the room, including a wooden floor and a doorway leading to another area. This observation does not contain any points of interest described in the Navigation Checkpoints at this stage.
#     Right: To my right is a doorway that leads to another room. The doorway is framed with a light-colored wood and has a small, rectangular mirror mounted on the wall above it. The wall adjacent to the doorway is covered with a light blue wallpaper featuring a floral pattern. There is also a radiator situated below the doorway, and a small section of the room beyond the doorway is visible, showing a glimpse of a fireplace and a rug on the floor.
#     Behind: To my behind is a doorway that appears to lead to another room. The doorway is framed with a dark material, possibly wood or a similar substance, and there is a mirror on the wall to the left of the doorway. The walls are adorned with patterned wallpaper, which adds a decorative element to the space. This observation does not contain any points of interest described in the Navigation Checkpoints, as the checkpoints are focused on specific actions and locations rather than the immediate surroundings.
#     Left: To my left is a hallway with a wooden floor. The walls are painted white, and there are two large black paintings hanging side by side on the left wall. The paintings are quite prominent and appear to be abstract in style. There is a closed white door at the end of the hallway, which is likely the doorway to the washroom mentioned in Checkpoint 2.
# Action Reasoning ----
# Current Location: In front of a glass door with a black frame.
#
# Reasoning: I have already achieved the Starting Point by identifying the glass door. I am now working toward Checkpoint 1, which requires me to turn around. Since I am currently facing the glass door, I need to turn to face behind me to accomplish this.
#
# Selected Action: Turn to face behind
# Taking action: Turn to face behind
# Current position: [  0.26      3.89145 -16.09   ]
# -------------------
#
# Step: 3
# Summary of past action(s): So far, I have been navigating through an indoor environment with the aim of reaching a series of Navigation Checkpoints. I began at the Starting Point, which positioned me in front of a glass door with a black frame. At this initial location, I had not yet achieved any Navigation Checkpoints or taken any actions.
#
# Recognizing that I was at the Starting Point, I determined the need to progress towards Checkpoint 1. I noted that Checkpoint 1 was located to my right, accessible through a doorway. To advance towards this checkpoint, I decided to turn around. My selected action was to turn to face behind me, which I executed.
#
# As a result of this action, I have now correctly turned around, which positions me closer to achieving Checkpoint 1. Although I have not yet completed any checkpoints at this stage, I am prepared to take further steps toward navigating to the doorway leading to the washroom as indicated in the upcoming Checkpoint 2.
# Observations:
#     Front: To my front is a doorway with a black frame, which appears to be the doorway leading to the washroom as described in Checkpoint 2.
#     Right: To my right is a doorway with a white door and a black door frame. The door is closed, and there is a small rectangular window or panel on the door. The floor is made of light-colored wood, and the walls are painted white. There are two large, dark-colored paintings or posters hanging on the wall to the left of the doorway.
#     Behind: To my behind is a doorway that appears to lead to another room. The doorway is framed with a dark material, possibly wood or metal, and is set against a wall with wallpaper that has a subtle pattern. Through the doorway, I can see a glimpse of a living area with a large window that allows natural light to enter the room. The window has a view of the outside, which includes some greenery and a structure that appears to be a house or a building. The floor in the visible part of the room is covered with a patterned rug, and there is a piece of furniture, possibly a chair or a table, near
#     Left: To my left is a hallway with a patterned wallpaper. The hallway features a radiator near the floor, a doorway leading to another room, and a mirror reflecting part of the hallway. There is also a door with a doorknob visible in the reflection of the mirror.
# Action Reasoning ----
# Current Location: In front of a doorway with a black frame leading to the washroom.
#
# Reasoning: I have completed Checkpoint 1 by turning around, and I am currently working toward Checkpoint 2, which involves walking towards the doorway of the washroom. Since the washroom doorway is in front of me, I need to ensure alignment first to proceed.
#
# Selected Action: Turn Left
# Taking action: Turn Left
# Current position: [  0.26      3.89145 -16.09   ]
# -------------------
#
# Step: 4
# Summary of past action(s): In my navigation through the indoor environment, I began at the Starting Point, which placed me in front of a glass door. At this initial location, I had not yet achieved any Navigation Checkpoints or taken any actions.
#
# Recognizing that my goal was to progress toward Checkpoint 1, I noted that it was located to my right through a doorway. To advance, I decided to turn around. I executed this action successfully, positioning myself closer to achieving Checkpoint 1. Although I had not yet completed any checkpoints at this stage, I was now facing the right direction to move forward.
#
# Upon turning around, I successfully reached Checkpoint 1. With that accomplished, I shifted my focus to Checkpoint 2, which instructed me to walk towards the doorway leading to the washroom. As I stood in front of the washroom doorway, my next objective was to ensure proper alignment for the upcoming movement.
#
# To achieve this, I selected the action to turn left. This action was necessary to align myself properly with the washroom doorway, allowing me to proceed to Checkpoint 2 effectively.
#
# At this point, I am in front of the doorway with the black frame, ready to take the next step towards entering the washroom.
# Observations:
#     Front: To my front is a doorway with a black frame, which appears to be the entrance to the washroom. The doorway is slightly ajar, and I can see a glimpse of the washroom interior through it. The washroom has a patterned wallpaper, and I can also see a radiator and a mirror on the wall. This observation aligns with Checkpoint 2, as it describes the doorway to the washroom that I am approaching.
#     Right: To my right is a doorway with a black frame, leading into a washroom. The doorway is slightly ajar, revealing a glimpse of the washroom interior. The walls of the doorway are adorned with a patterned wallpaper, adding a decorative touch to the space. The floor appears to be made of wooden tiles, and there is a mirror mounted on the wall, reflecting part of the room. This observation aligns with Checkpoint 2, as it describes the doorway to the washroom that I am approaching.
#     Behind: To my behind is a white door with a black frame, which appears to be the doorway leading to the washroom. The door is closed, and there are two large black paintings hanging on the wall next to it. This observation aligns with Checkpoint 2, as it describes the doorway to the washroom that I am supposed to walk towards and enter.
#     Left: To my left is a doorway with a black frame, which appears to be the entrance to the washroom. This doorway is the point of interest described in Checkpoint 2, as it is the doorway to the washroom where I am instructed to walk towards and enter.
# Action Reasoning ----
# Current Location: In front of the doorway to the washroom
# Reasoning: I have not yet achieved Checkpoint 2, which is to walk towards the doorway and inside the washroom. Since all observations confirm that I am in front of the washroom doorway, I need to turn towards the washroom. Facing the doorway is already aligned with my current position.
# Selected Action: Turn Left
# Taking action: Turn Left
# Current position: [  0.26      3.89145 -16.09   ]
# -------------------
#
# Step: 5
# Summary of past action(s): In my navigation through the indoor environment, I began at the Starting Point, which placed me in front of a glass door. At this initial location, I had not yet achieved any Navigation Checkpoints or taken any actions.
#
# Recognizing that my goal was to progress toward Checkpoint 1, which indicated that a doorway was located to my right, I decided to turn around. I executed this action successfully, positioning myself closer to achieving Checkpoint 1. Upon turning around, I was able to reach Checkpoint 1 successfully.
#
# With Checkpoint 1 completed, I shifted my focus to Checkpoint 2, which instructed me to walk toward the doorway leading to the washroom. I navigated to the washroom doorway and found myself standing in front of it. To ensure I was properly aligned for my next movement, I determined that I needed to turn left to face the doorway correctly.
#
# Thus, I selected the action to turn left, aware that this would align me with the washroom doorway, allowing me to proceed effectively towards Checkpoint 2. As of now, I am in front of the doorway with the black frame, prepared to take the next step towards entering the washroom. Thus far, I have achieved Checkpoint 1 and am on the verge of completing Checkpoint 2.
# Observations:
#     Front: To my front is a doorway with a black frame, which appears to be the entrance to the washroom. The doorway is slightly ajar, and through it, I can see a glimpse of the interior of the washroom. The washroom has a light-colored floor and a large window that allows natural light to enter, illuminating the space. The walls of the washroom are painted in a light color, and there is a visible light fixture on the ceiling. This observation aligns with Checkpoint 2, as it describes the doorway to the washroom that I am approaching.
#     Right: To my right is a doorway with a black frame, which aligns with the instruction to walk towards the doorway leading to the washroom. This observation contains the point of interest described in Checkpoint 2, as it indicates the correct doorway to enter the washroom.
#     Behind: To my behind is a doorway with a black frame, leading into a room that appears to be a washroom. The walls are adorned with patterned wallpaper, and there is a mirror visible on the wall. This observation aligns with Checkpoint 2, as it describes the doorway to the washroom that I am approaching.
#     Left: To my left is a hallway with a wooden floor. The walls are painted white, and there are two large black paintings hanging side by side on the left wall. The paintings are quite prominent and appear to be abstract in style. There is a white door at the end of the hallway, which is the doorway to the washroom as described in Checkpoint 2.
# Action Reasoning ----
# Current Location: In front of the doorway leading to the washroom
# Reasoning: I have already achieved Checkpoint 1 and am currently working toward Checkpoint 2, which involves entering the washroom. The doorway is slightly ajar and I should walk towards it. Since I cannot move forward, I need to turn to face the doorway directly, which is in front of me.
# Selected Action: Turn Left
# Taking action: Turn Left
# Current position: [  0.26      3.89145 -16.09   ]
# -------------------
#
# Actions taken: ['Turn Right', 'Turn to face behind', 'Turn Left', 'Turn Left', 'Turn Left']
# Final distance to goal: 2.6091415882110596

# %%
scan_id = next(iter(outputs.keys()))
instruction_id = next(iter(outputs[scan_id].keys()))
print(f'scan_id: {scan_id}')
print(f'instruction_id: {instruction_id}')
# Out:
# scan_id: SN83YJsR3w2
# instruction_id: 0

# %%
start = outputs[scan_id][instruction_id]['visited_points']
end = outputs[scan_id][instruction_id]['gold_path'][-1]
print(start)
print(end)
# Out:
# [array([  0.26   ,   3.89145, -16.09   ], dtype=float32), array([  0.26   ,   3.89145, -16.09   ], dtype=float32), array([  0.26   ,   3.89145, -16.09   ], dtype=float32), array([  0.26   ,   3.89145, -16.09   ], dtype=float32), array([  0.26   ,   3.89145, -16.09   ], dtype=float32)]
# [  1.07   5.35 -18.57]

# %%
update_scene_path(scan_id)
cfg = make_cfg(sim_settings)
sim = habitat_sim.Simulator(cfg)
agent = sim.get_agent(0)
# Out:
# Renderer: NVIDIA GeForce RTX 4090/PCIe/SSE2 by NVIDIA Corporation
# OpenGL version: 4.6.0 NVIDIA 550.120
# Using optional features:
#     GL_ARB_vertex_array_object
#     GL_ARB_separate_shader_objects
#     GL_ARB_robustness
#     GL_ARB_texture_storage
#     GL_ARB_texture_view
#     GL_ARB_framebuffer_no_attachments
#     GL_ARB_invalidate_subdata
#     GL_ARB_texture_storage_multisample
#     GL_ARB_multi_bind
#     GL_ARB_direct_state_access
#     GL_ARB_get_texture_sub_image
#     GL_ARB_texture_filter_anisotropic
#     GL_KHR_debug
#     GL_KHR_parallel_shader_compile
#     GL_NV_depth_buffer_float
# Using driver workarounds:
#     no-forward-compatible-core-context
#     nv-egl-incorrect-gl11-function-pointers
#     no-layout-qualifiers-on-old-glsl
#     nv-zero-context-profile-mask
#     nv-implementation-color-read-format-dsa-broken
#     nv-cubemap-inconsistent-compressed-image-size
#     nv-cubemap-broken-full-compressed-image-query
#     nv-compressed-block-size-in-bits
# PluginManager::Manager: duplicate static plugin StbImageImporter, ignoring
# PluginManager::Manager: duplicate static plugin GltfImporter, ignoring
# PluginManager::Manager: duplicate static plugin BasisImporter, ignoring
# PluginManager::Manager: duplicate static plugin AssimpImporter, ignoring
# PluginManager::Manager: duplicate static plugin AnySceneImporter, ignoring
# PluginManager::Manager: duplicate static plugin AnyImageImporter, ignoring
# [22:04:10:446634]:[Warning]:[Metadata] SceneDatasetAttributes.cpp(107)::addNewSceneInstanceToDataset : Dataset : 'mp3d' : Lighting Layout Attributes 'no_lights' specified in Scene Attributes but does not exist in dataset, so creating default.

# %%
distances_to_goal = find_geodesic_distance(start, end)
print(f'Distance from ending point: {distances_to_goal[-1]}')

# Mapping:
# Creating map
topdown_map = draw_map(agent, scan_id)

# Printing map
nav_points = convert_points_to_topdown(
    sim.pathfinder, outputs[scan_id][instruction_id]['visited_points']
)

gold_path = convert_points_to_topdown(
    sim.pathfinder, outputs[scan_id][instruction_id]['gold_path']
)

display_map(topdown_map, key_points = nav_points, gold_path = gold_path)
# Out:
# Distance from ending point: 2.6091415882110596
# Showing map for scene: SN83YJsR3w2
# The NavMesh bounds are: (array([-15.947373,  -3.70855 , -23.05046 ], dtype=float32), array([13.103234,  8.683314, 17.686918], dtype=float32))

# %%
plt.plot(np.arange(len(distances_to_goal)), distances_to_goal, marker='o')
plt.show()

# %%
# Draws the step-by-step observations for a single experience
def draw_observations(observations, text_observations, actions, reasoning):
    width = 8
    observation_order = ["forward", "right", "behind", "left"]
    
    fig, axs = plt.subplots(len(observations), 4, figsize=(width, 1.8*width))
    
    first_title_x_pos = 0.21

    # Print headings
    for i, direction in enumerate(observation_order):
        fig.text(first_title_x_pos + (0.2 * i), 0.88, direction, ha='center', fontsize=10)

    # For each action
    for step in range(len(observations)):
        # Print left-heading
        fig.text(-0.5, 0.6 + (-0.05 * step), f'Obsv: {step+1}', fontsize=10, transform=axs[step,0].transAxes)

        # Print text to right
        if step != len(observations)-1:
            fig.text(len(observation_order)+1, 0.4 + (-0.06 * step), f'Reasoning decided: {reasoning[step]}', fontsize=8, transform=axs[step,0].transAxes)#, wrap=True)

        # Draw observations
        for i in range(4):
            axs[step,i].imshow(observations[step][observation_order[i]])
            axs[step,i].axis('off')
    
    #plt.tight_layout()
    plt.show()
    return

print(outputs[scan_id][instruction_id]['inferred_nav_instructions'])
draw_observations(outputs[scan_id][instruction_id]['observations'],
                  outputs[scan_id][instruction_id]['text_observations'],
                  outputs[scan_id][instruction_id]['actions'],
                  outputs[scan_id][instruction_id]['reasoning']
                 )
# Out:
# Starting Point: You are standing in front of a glass door.
# Checkpoint 1: On your right is a doorway. Turn around.
# Checkpoint 2: You will see a doorway to the washroom. Walk towards the doorway and inside the washroom.
# Checkpoint 3: Stand in between the sink and the bathtub. Once you're there, you're done.
